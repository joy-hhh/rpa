# %%
import pandas as pd
import numpy as np

val = pd.read_excel("values.xlsx")
val
# Out:
#       ppe1     ppe2    ppe3       ppe4       ppe5      ppe6    ppe7    ppe8  \
# 0   594246  -510380   83866   535880.0  -461896.0   73984.0   73984   58366
# 1   603467  -302897  300570   455649.0  -332633.0  123016.0  123015  240709
# 2  1233306 -1053649  179657  1043338.0  -938068.0  105270.0  105270  189968
# 3   154610        0  154610  2034867.0 -1732597.0  302270.0       0  154610
# 4  2585629 -1866926  718703        NaN        NaN       NaN  302269  643653
#
#     ppe9   ppe10  ...        as3        as4        as5        as6        as7  \
# 0      0  -48484  ...        0.0    81345.0    81345.0        0.0        0.0
# 1 -27941  -35213  ... -3185444.0  1990249.0   928104.0  3297986.0 -2856568.0
# 2      0 -115581  ... -3185444.0  2071594.0  1009449.0  3297986.0 -2856568.0
# 3      0       0  ...        NaN        NaN        NaN        NaN        NaN
# 4 -27941 -199278  ...        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
dict ={}
for i in list(val.columns):
    # print(val[i])
    
    # 변수 = 컬럼명 + 규칙
    
    for j in range(len(val[i])): 
        if np.isnan(val[i][j]):
            continue
        else: 
            dict[i+str(j)] = val[i][j]

# series = pd.Series(dict)
# series.dropna()        
# dic = series.to_dict()
dict
# Out:
# {'ppe10': 594246,
#  'ppe11': 603467,
#  'ppe12': 1233306,
#  'ppe13': 154610,
#  'ppe14': 2585629,
#  'ppe20': -510380,
#  'ppe21': -302897,
#  'ppe22': -1053649,
#  'ppe23': 0,
#  'ppe24': -1866926,
#  'ppe30': 83866,
#  'ppe31': 300570,
#  'ppe32': 179657,
#  'ppe33': 154610,
#  'ppe34': 718703,
#  'ppe40': 535880.0,
#  'ppe41': 455649.0,
#  'ppe42': 1043338.0,
#  'ppe43': 2034867.0,
#  'ppe50': -461896.0,
#  'ppe51': -332633.0,
#  'ppe52': -938068.0,
#  'ppe53': -1732597.0,
#  'ppe60': 73984.0,
#  'ppe61': 123016.0,
#  'ppe62': 105270.0,
#  'ppe63': 302270.0,
#  'ppe70': 73984,
#  'ppe71': 123015,
#  'ppe72': 105270,
#  'ppe73': 0,
#  'ppe74': 302269,
#  'ppe80': 58366,
#  'ppe81': 240709,
#  'ppe82': 189968,
#  'ppe83': 154610,
#  'ppe84': 643653,
#  'ppe90': 0,
#  'ppe91': -27941,
#  'ppe92': 0,
#  'ppe93': 0,
#  'ppe94': -27941,
#  'ppe100': -48484,
#  'ppe101': -35213,
#  'ppe102': -115581,
#  'ppe103': 0,
#  'ppe104': -199278,
#  'ppe110': 83867,
#  'ppe111': 300570,
# ...

# %%
dic = pd.Series(dict)

# %%
dic.to_excel("var.xlsx")
